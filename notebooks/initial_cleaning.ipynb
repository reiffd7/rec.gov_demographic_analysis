# %%
# !pip install uszipcode
# !pip install censusgeocode
# !pip install geopy
# !pip install pgeocode

import numpy as np
import pandas as pd
import pyspark as ps# for the pyspark suite
import helper9 as h

spark = ps.sql.SparkSession.builder \
            .master("local[4]") \
            .appName("case study") \
            .getOrCreate()

sc = spark.sparkContext
# Out:
# Requirement already satisfied: uszipcode in /opt/conda/lib/python3.7/site-packages (0.2.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from uszipcode) (2.22.0)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.7/site-packages (from uszipcode) (1.3.6)
# Requirement already satisfied: pathlib-mate in /opt/conda/lib/python3.7/site-packages (from uszipcode) (0.0.15)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.7/site-packages (from uszipcode) (19.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->uszipcode) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->uszipcode) (1.25.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->uszipcode) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->uszipcode) (3.0.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from pathlib-mate->uszipcode) (1.12.0)
# Requirement already satisfied: autopep8 in /opt/conda/lib/python3.7/site-packages (from pathlib-mate->uszipcode) (1.4.4)
# Requirement already satisfied: pycodestyle>=2.4.0 in /opt/conda/lib/python3.7/site-packages (from autopep8->pathlib-mate->uszipcode) (2.5.0)
# Requirement already satisfied: censusgeocode in /opt/conda/lib/python3.7/site-packages (0.4.3.post1)
# Requirement already satisfied: requests[security]<3,>=2.18 in /opt/conda/lib/python3.7/site-packages (from censusgeocode) (2.22.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from censusgeocode) (1.12.0)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from censusgeocode) (0.9.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests[security]<3,>=2.18->censusgeocode) (1.25.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests[security]<3,>=2.18->censusgeocode) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests[security]<3,>=2.18->censusgeocode) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests[security]<3,>=2.18->censusgeocode) (3.0.4)
# Requirement already satisfied: pyOpenSSL>=0.14; extra == "security" in /opt/conda/lib/python3.7/site-packages (from requests[security]<3,>=2.18->censusgeocode) (19.0.0)
# Requirement already satisfied: cryptography>=1.3.4; extra == "security" in /opt/conda/lib/python3.7/site-packages (from requests[security]<3,>=2.18->censusgeocode) (2.7)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /opt/conda/lib/python3.7/site-packages (from cryptography>=1.3.4; extra == "security"->requests[security]<3,>=2.18->censusgeocode) (1.12.3)
# Requirement already satisfied: asn1crypto>=0.21.0 in /opt/conda/lib/python3.7/site-packages (from cryptography>=1.3.4; extra == "security"->requests[security]<3,>=2.18->censusgeocode) (0.24.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.3.4; extra == "security"->requests[security]<3,>=2.18->censusgeocode) (2.19)
# Requirement already satisfied: geopy in /opt/conda/lib/python3.7/site-packages (1.20.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/lib/python3.7/site-packages (from geopy) (1.49)
# Requirement already satisfied: pgeocode in /opt/conda/lib/python3.7/site-packages (0.1.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from pgeocode) (0.25.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from pgeocode) (1.17.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from pgeocode) (2.22.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas->pgeocode) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas->pgeocode) (2019.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->pgeocode) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->pgeocode) (1.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.12.0)

# %%
rdd = sc.textFile('reservations2018.csv')\
        .map(h.parse_rows)\
        .map(h.caster)\
        .map(h.state_filter)\
        .map(h.cust_country_filter)\
        .map(h.clean_zips)\
        .map(h.five_zips)\
        .map(h.add_coords)\
        .map(h.distance)\

# %%
rdd.count()
# Out:
# 3424272

# %%
from pyspark.sql.types import *
res_schema = StructType([
    StructField('Res_ID', StringType(),True),
    StructField('Location', StringType(), True),
    StructField('Park', StringType(),True),
    StructField('SiteType', StringType(),True), 
    StructField('UseType', StringType(),True),
    StructField('FacState', StringType(),True),
    StructField('FacLong', FloatType(),True),
    StructField('FacLat', FloatType(),True),
    StructField('CustZIP', StringType(),True),
    StructField('CustCountry', StringType(),True),
    StructField('CustSize', IntegerType(),True),
    StructField('CustState', StringType(), True),
    StructField('CustLat', FloatType(),True),
    StructField('CustLong', FloatType(),True),
    StructField('Dist', FloatType(), True)])

# %%
res_df = spark.createDataFrame(rdd.filter(bool), res_schema)
res_df.show(2)
# Out:
# +----------+-----------------+--------------------+--------------------+---------+--------+-----------+-------+-------+-----------+--------+---------+-------+--------+---------+
# |    Res_ID|         Location|                Park|            SiteType|  UseType|FacState|    FacLong| FacLat|CustZIP|CustCountry|CustSize|CustState|CustLat|CustLong|     Dist|
# +----------+-----------------+--------------------+--------------------+---------+--------+-----------+-------+-------+-----------+--------+---------+-------+--------+---------+
# |3034963543|RIO GRANDE NF- FS|Aspen Glade --- F...|STANDARD NONELECTRIC|Overnight|      CO|-106.273056|37.0725|  80923|        USA|       2|       CO|  38.92| -104.71|246.77235|
# |3051273848|RIO GRANDE NF- FS|Aspen Glade --- F...|STANDARD NONELECTRIC|Overnight|      CO|-106.273056|37.0725|  87015|        USA|       8|       NM|   35.1|  -106.2| 218.9687|
# +----------+-----------------+--------------------+--------------------+---------+--------+-----------+-------+-------+-----------+--------+---------+-------+--------+---------+
# only showing top 2 rows

# %%
res_df1 = res_df.toPandas()
res_df1
# Out:
#             Res_ID              Location                      Park  \
# 0       3034963543     RIO GRANDE NF- FS    Aspen Glade --- FPIN24
# 1       3051273848     RIO GRANDE NF- FS    Aspen Glade --- FPIN24
# 2       3051863567     RIO GRANDE NF- FS    Aspen Glade --- FPIN24
# 3       3063451302     RIO GRANDE NF- FS    Aspen Glade --- FPIN24
# 4       3068573240     RIO GRANDE NF- FS    Aspen Glade --- FPIN24
# ...            ...                   ...                       ...
# 128760  3212005879  Intermountain Region  Mesa Verde National Park
# 128761  3216737721  Intermountain Region  Mesa Verde National Park
# 128762  3220672164  Intermountain Region  Mesa Verde National Park
# 128763  3222593345  Intermountain Region  Mesa Verde National Park
# 128764  3222640714  Intermountain Region  Mesa Verde National Park
#
#                     SiteType    UseType FacState     FacLong     FacLat  \
# 0       STANDARD NONELECTRIC  Overnight       CO -106.273056  37.072498
# 1       STANDARD NONELECTRIC  Overnight       CO -106.273056  37.072498
# 2       STANDARD NONELECTRIC  Overnight       CO -106.273056  37.072498
# 3       STANDARD NONELECTRIC  Overnight       CO -106.273056  37.072498
# 4       STANDARD NONELECTRIC  Overnight       CO -106.273056  37.072498
# ...                      ...        ...      ...         ...        ...
# 128760         Historic Tour                  CO -108.489998  37.200001
# 128761         Historic Tour                  CO -108.489998  37.200001
# 128762         Historic Tour                  CO -108.489998  37.200001
# 128763         Historic Tour                  CO -108.489998  37.200001
# 128764         Historic Tour                  CO -108.489998  37.200001
#
#        CustZIP CustCountry  CustSize CustState    CustLat    CustLong  \
# 0        80923         USA         2        CO  38.919998 -104.709999
# 1        87015         USA         8        NM  35.099998 -106.199997
# 2        80021         USA         2        CO  39.900002 -105.120003
# 3        75116         USA         2        TX  32.660000  -96.919998
# 4        55447         USA         3        MN  45.009998  -93.489998
# ...        ...         ...       ...       ...        ...         ...
# 128760   97009         USA         2        OR  45.419998 -122.339996
# 128761   81328         USA         2        CO  37.299999 -108.300003
# 128762   80122         USA         2        CO  39.580002 -104.959999
# 128763   01886         USA         1        MA  42.590000  -71.440002
# 128764   95301         USA         1        CA  37.320000 -120.629997
#
#                Dist
# 0        246.772354
# 1        218.968704
# 2        329.588440
# 3        984.677185
# 4       1387.145630
# ...             ...
# 128760  1472.414307
# 128761    20.181925
# 128762   406.023315
# 128763  3198.287598
# 128764  1076.252930
#
# [128765 rows x 15 columns]

# %%
res_df1.to_csv('co_sites.csv', index=False)
